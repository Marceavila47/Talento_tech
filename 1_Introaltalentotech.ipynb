# %% [markdown]
# <a href="https://colab.research.google.com/github/Marceavila47/Talento_tech/blob/main/1_Introaltalentotech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#establezco la conexion con mi fuente y con el dataset de prueba, ventas.xlsx
path = '/content/drive/MyDrive/Colab Notebooks/Talento tech/data/ventas.xlsx'

# %% [markdown]
# #

# %% [markdown]
# Practica 1 de Talennto Tech: Incluye importar un dataset

# %%
#importamos la libreria pandas para la manipulacion de datos
import pandas as pd

# %%
#creamos un dataframe de pandas con los datos suministrados
df_ventas = pd.read_excel(path)

# %%
#Muestra la lista con los nombres de las columnas del dataframe
df_ventas.columns
# Out:
# Index(['Fecha', 'Region', 'Producto', 'Vendedor', 'Ventas'], dtype='object')

# %%
# muestra las ultimas filas del dataframa
df_ventas.tail()
# Out:
#         Fecha Region      Producto Vendedor  Ventas
# 13 2024-02-13  Oeste    Accesorios     Sara    5442
# 14 2024-02-14  Oeste  Dispositivos    Kevin   10711
# 15 2024-02-15  Oeste  Dispositivos     Sara    8780
# 16 2024-02-16  Oeste      Sistemas    Kevin   32855
# 17 2024-02-17  Oeste      Sistemas     Sara   23151
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Ventas'].plot(kind='hist', bins=20, title='Ventas')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Producto').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# ...

# %%
from matplotlib import pyplot as plt
_df_0['Ventas'].plot(kind='hist', bins=20, title='Ventas')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#muestra las primeras filas del dataframe
df_ventas.head()
# Out:
#        Fecha   Region      Producto Vendedor  Ventas
# 0 2024-01-31  Central    Accesorios    David    8287
# 1 2024-02-01  Central    Accesorios    Karen    6909
# 2 2024-02-02  Central  Dispositivos    David   11420
# 3 2024-02-03  Central  Dispositivos    Karen   12948
# 4 2024-02-04  Central      Sistemas    David   20098

# %%
#muestra la informacion del dataset
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Fecha     18 non-null     datetime64[ns]
#  1   Region    18 non-null     object
#  2   Producto  18 non-null     object
#  3   Vendedor  18 non-null     object
#  4   Ventas    18 non-null     int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 848.0+ bytes

# %%
#proporciona la estadistica descriptiva del dataframe
df_ventas.describe()
# Out:
#                      Fecha        Ventas
# count                   18     18.000000
# mean   2024-02-08 12:00:00  13307.388889
# min    2024-01-31 00:00:00   4744.000000
# 25%    2024-02-04 06:00:00   8410.250000
# 50%    2024-02-08 12:00:00  10529.500000
# 75%    2024-02-12 18:00:00  13491.750000
# max    2024-02-17 00:00:00  32855.000000
# std                    NaN   8153.055776

# %%
from matplotlib import pyplot as plt
_df_6['Ventas'].plot(kind='line', figsize=(8, 4), title='Ventas')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_4['Ventas'].plot(kind='hist', bins=20, title='Ventas')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt

# %%
df_1.groupby('Fecha').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-00925edc268e> in <cell line: 1>()
# ----> 1 df_1.groupby('Fecha').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
#       2 plt.gca().spines[['top', 'right',]].set_visible(False)
#
# NameError: name 'df_1' is not defined

# %%
df_0['Ventas'].plot(kind='hist', bins=20, title='Ventas')
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-47c733db5063> in <cell line: 1>()
# ----> 1 df_0['Ventas'].plot(kind='hist', bins=20, title='Ventas')
#       2 plt.gca().spines[['top', 'right',]].set_visible(False)
#
# NameError: name 'df_0' is not defined

# %%
from matplotlib import pyplot as plt
_df_8['Ventas'].plot(kind='hist', bins=20, title='Ventas')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#devuelve una tupla con los nombres de las columnas del dataframe
df_ventas.shape
# Out:
# (18, 5)

# %%
from matplotlib import pyplot as plt
_df_10['Ventas'].plot(kind='line', figsize=(8, 4), title='Ventas')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
#Ejercicio 1: Mostrar las primeras filas del dataframe
print(df_ventas.head(5))
# Out:
#        Fecha   Region      Producto Vendedor  Ventas
# 0 2024-01-31  Central    Accesorios    David    8287
# 1 2024-02-01  Central    Accesorios    Karen    6909
# 2 2024-02-02  Central  Dispositivos    David   11420
# 3 2024-02-03  Central  Dispositivos    Karen   12948
# 4 2024-02-04  Central      Sistemas    David   20098

# %%
#Ejercicio2. Calcular el total de ventas por region
#se requiere el groupby para agrupar el total de ventas por region
ventas_por_region = df_ventas.groupby("Region")['Ventas'].sum()
print(ventas_por_region)
print("\n")
print(df_ventas.head(10))
# Out:
# Region
# Central    90295
# Este       63555
# Oeste      85683
# Name: Ventas, dtype: int64
#
#
#        Fecha   Region      Producto Vendedor  Ventas
# 0 2024-01-31  Central    Accesorios    David    8287
# 1 2024-02-01  Central    Accesorios    Karen    6909
# 2 2024-02-02  Central  Dispositivos    David   11420
# 3 2024-02-03  Central  Dispositivos    Karen   12948
# 4 2024-02-04  Central      Sistemas    David   20098
# 5 2024-02-05  Central      Sistemas    Karen   30633
# 6 2024-02-06     Este    Accesorios      Ana    9323
# 7 2024-02-07     Este    Accesorios    Lucas    7667
# 8 2024-02-08     Este  Dispositivos      Ana   10348
# 9 2024-02-09     Este  Dispositivos    Lucas    9312

# %%
#Ejercicio3. Filtrar el dataframe para mostrar solo las ventas realizadas por David
ventas_david = df_ventas [df_ventas['Vendedor'] == 'David']
print(ventas_david)
# Out:
#        Fecha   Region      Producto Vendedor  Ventas
# 0 2024-01-31  Central    Accesorios    David    8287
# 2 2024-02-02  Central  Dispositivos    David   11420
# 4 2024-02-04  Central      Sistemas    David   20098

# %%
#Ejercicio 2. Calcular el total de ventas por region
ventas_por_region = df_ventas .groupby("Region")['Ventas'].sum()
print(ventas_por_region)
# Out:
# Region
# Central    90295
# Este       63555
# Oeste      85683
# Name: Ventas, dtype: int64

# %%
ventas_por_region = df_ventas .groupby("Producto")['Ventas'].sum()
print(ventas_por_region)
# Out:
# Producto
# Accesorios       42372
# Dispositivos     63519
# Sistemas        133642
# Name: Ventas, dtype: int64

# %%
ventas_por_region = df_ventas .groupby("Vendedor")['Ventas'].sum()
print(ventas_por_region)
# Out:
# Vendedor
# Ana      33202
# David    39805
# Karen    50490
# Kevin    48310
# Lucas    30353
# Sara     37373
# Name: Ventas, dtype: int64

# %%
#calcular el total de ventas por region
ventas_total = df_ventas ['Ventas'].sum()
print(f"ventas_totales de los productos por region:",ventas_total)
# Out:
# ventas_totales de los productos por region: 239533

# %%
#Ejercicio 4. Calcular el promedio de las ventas por region (procedimiento sugerido por la IA)
ventas_promedio = df_ventas ['Ventas'].mean()
print(f"ventas_promedio de los productos por region:",ventas_promedio)
# Out:
# ventas_promedio de los productos por region: 13307.388888888889

# %%
#Ejercicio 4. Calcular el promedio de las ventas por region (como se hizo en la clase)
ventas_por_producto = df_ventas.groupby('Region')['Ventas'].mean()
print(ventas_por_producto)
# Out:
# Region
# Central    15049.166667
# Este       10592.500000
# Oeste      14280.500000
# Name: Ventas, dtype: float64

# %%
#Ejercicio 5. Calcular el promedio de las ventas por region conn dos decimales
ventas_por_producto = df_ventas.groupby('Region')['Ventas'].mean().round(2)
print(ventas_por_producto)
# Out:
# Region
# Central    15049.17
# Este       10592.50
# Oeste      14280.50
# Name: Ventas, dtype: float64

# %%
#Ejercicio 6. Ordenar el dataframe por ventas en orden descendente
df_ordenado = df_ventas.sort_values(by='Ventas', ascending=False)
print(df_ordenado)
# Out:
#         Fecha   Region      Producto Vendedor  Ventas
# 16 2024-02-16    Oeste      Sistemas    Kevin   32855
# 5  2024-02-05  Central      Sistemas    Karen   30633
# 17 2024-02-17    Oeste      Sistemas     Sara   23151
# 4  2024-02-04  Central      Sistemas    David   20098
# 10 2024-02-10     Este      Sistemas      Ana   13531
# 11 2024-02-11     Este      Sistemas    Lucas   13374
# 3  2024-02-03  Central  Dispositivos    Karen   12948
# 2  2024-02-02  Central  Dispositivos    David   11420
# 14 2024-02-14    Oeste  Dispositivos    Kevin   10711
# 8  2024-02-08     Este  Dispositivos      Ana   10348
# 6  2024-02-06     Este    Accesorios      Ana    9323
# 9  2024-02-09     Este  Dispositivos    Lucas    9312
# 15 2024-02-15    Oeste  Dispositivos     Sara    8780
# 0  2024-01-31  Central    Accesorios    David    8287
# 7  2024-02-07     Este    Accesorios    Lucas    7667
# 1  2024-02-01  Central    Accesorios    Karen    6909
# ...

# %%
#Ejercicio 7. Filtrar las filas con ventas mayores a 10000 y oedenar de mayor a menor
df_filtrado = df_ventas[df_ventas['Ventas'] > 10000]. sort_values(by='Ventas', ascending= True)
print(df_filtrado)
print("\n")
# Out:
#         Fecha   Region      Producto Vendedor  Ventas
# 8  2024-02-08     Este  Dispositivos      Ana   10348
# 14 2024-02-14    Oeste  Dispositivos    Kevin   10711
# 2  2024-02-02  Central  Dispositivos    David   11420
# 3  2024-02-03  Central  Dispositivos    Karen   12948
# 11 2024-02-11     Este      Sistemas    Lucas   13374
# 10 2024-02-10     Este      Sistemas      Ana   13531
# 4  2024-02-04  Central      Sistemas    David   20098
# 17 2024-02-17    Oeste      Sistemas     Sara   23151
# 5  2024-02-05  Central      Sistemas    Karen   30633
# 16 2024-02-16    Oeste      Sistemas    Kevin   32855

# %%
#Ejercicio 8. Calcular el total por ventas en orden ascendente
df_ordenado = df_ventas.sort_values(by='Ventas', ascending=True)
print(df_ordenado)
print ("\n")
# Out:
#         Fecha   Region      Producto Vendedor  Ventas
# 12 2024-02-12    Oeste    Accesorios    Kevin    4744
# 13 2024-02-13    Oeste    Accesorios     Sara    5442
# 1  2024-02-01  Central    Accesorios    Karen    6909
# 7  2024-02-07     Este    Accesorios    Lucas    7667
# 0  2024-01-31  Central    Accesorios    David    8287
# 15 2024-02-15    Oeste  Dispositivos     Sara    8780
# 9  2024-02-09     Este  Dispositivos    Lucas    9312
# 6  2024-02-06     Este    Accesorios      Ana    9323
# 8  2024-02-08     Este  Dispositivos      Ana   10348
# 14 2024-02-14    Oeste  Dispositivos    Kevin   10711
# 2  2024-02-02  Central  Dispositivos    David   11420
# 3  2024-02-03  Central  Dispositivos    Karen   12948
# 11 2024-02-11     Este      Sistemas    Lucas   13374
# 10 2024-02-10     Este      Sistemas      Ana   13531
# 4  2024-02-04  Central      Sistemas    David   20098
# 17 2024-02-17    Oeste      Sistemas     Sara   23151
# ...

# %%
#Ejercicio 9. Eliminar la columa "Vendedor"
df_sin_vendedor = df_ventas.drop(columns=["Vendedor"])
print(df_sin_vendedor)
print("\n")
# Out:
#         Fecha   Region      Producto  Ventas
# 0  2024-01-31  Central    Accesorios    8287
# 1  2024-02-01  Central    Accesorios    6909
# 2  2024-02-02  Central  Dispositivos   11420
# 3  2024-02-03  Central  Dispositivos   12948
# 4  2024-02-04  Central      Sistemas   20098
# 5  2024-02-05  Central      Sistemas   30633
# 6  2024-02-06     Este    Accesorios    9323
# 7  2024-02-07     Este    Accesorios    7667
# 8  2024-02-08     Este  Dispositivos   10348
# 9  2024-02-09     Este  Dispositivos    9312
# 10 2024-02-10     Este      Sistemas   13531
# 11 2024-02-11     Este      Sistemas   13374
# 12 2024-02-12    Oeste    Accesorios    4744
# 13 2024-02-13    Oeste    Accesorios    5442
# 14 2024-02-14    Oeste  Dispositivos   10711
# 15 2024-02-15    Oeste  Dispositivos    8780
# 16 2024-02-16    Oeste      Sistemas   32855
# 17 2024-02-17    Oeste      Sistemas   23151

# %% [markdown]
# # Nueva sección

# %%
# EJERCICIO CON DATASET PERSONA
#cargar en el notebook los tres dataset de persona
# Especificamos la ruta del dataset en el drive

import pandas as pd
file_path = "/content/drive/MyDrive/Talento tech 2024/DATASET1_1.csv"

# Leemos el dataset con la libreria Pandas
df_persona = pd.read_csv(file_path, delimiter = ";")

# Imprimimos el Dataframe
print(df_persona)
# Out:
#    id  weight  height  age gender
# 0   1   144.5     5.9   33      M
# 1   2   167.2     5.4   45      M
# 2   3   124.1     5.2   23      F
# 3   4   144.5     5.9   33      M
# 4   5   133.2     5.7   54      F
# 5   3   124.1     5.2   23      F
# 6   7   129.2     5.3   42      M

# %%
df_persona.head()
# Out:
#    id weight height  age gender
# 0   1  144,5    5,9   33      M
# 1   2  167,2    5,4   45      M
# 2   3  124,1    5,2   23      F
# 3   4  144,5    5,9   33      M
# 4   5  133,2    5,7   54      F

# %%
#cambiar el nombre de las columnas en el df_persona (weight, height, age, gender)
df_persona.rename(columns={"weight": "Peso", "height": "Altura", "age": "Edad", "gender": "Genero"}, inplace=True)
print(df_persona)
# Out:
#    id   Peso Altura  Edad Genero
# 0   1  144,5    5,9    33      M
# 1   2  167,2    5,4    45      M
# 2   3  124,1    5,2    23      F
# 3   4  144,5    5,9    33      M
# 4   5  133,2    5,7    54      F
# 5   3  124,1    5,2    23      F
# 6   7  129,2    5,3    42      M

# %%
#cambiar el nombre de las columnas del df_persona y creamos el dataframe llamado df_nombres
#(weight, height, age, gender)
df_nombres = df_persona.rename(columns={"weight": "Peso", "height": "Altura", "age": "Edad", "gender": "Genero"})
print(df_nombres)
# Out:
#    id   Peso Altura  Edad Genero
# 0   1  144,5    5,9    33      M
# 1   2  167,2    5,4    45      M
# 2   3  124,1    5,2    23      F
# 3   4  144,5    5,9    33      M
# 4   5  133,2    5,7    54      F
# 5   3  124,1    5,2    23      F
# 6   7  129,2    5,3    42      M

# %%
#transformar los valores de peso y estatura
#Factores de conversion
lbs_to_kg = 0.453592
estatura_to_mt = 0.3048

#crear un dataframe llamado df_convertido

df_convertido = df_nombres

#convertir peso a kilogramos
#df_convertido["Peso_nuevo"] = df_convertido['Peso'] * lbs_to_kg

#convertir estatura a metros
#df_convertido['Estatura'] = df_convertido['Estatura'] * estatura_to_mt.round(2)


#convertir peso a kilogramos

#df_convertido['Peso'] = df_convertido['Peso'] * lbs_to_kg

#mostrar el dataframe actualizado
print(df_convertido.head())
# Out:
#    id   Peso Altura  Edad Genero
# 0   1  144,5    5,9    33      M
# 1   2  167,2    5,4    45      M
# 2   3  124,1    5,2    23      F
# 3   4  144,5    5,9    33      M
# 4   5  133,2    5,7    54      F

# %%
df_select = df_convertido[('id', 'Peso_kg', 'Estatura-Mts', 'Edad', 'Genero')]
print(df_select)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8e0a9965c0e5> in <cell line: 1>()
# ----> 1 df_select = df_convertido[('id', 'Peso_kg', 'Estatura-Mts', 'Edad', 'Genero')]
#       2 print(df_select)
#
# NameError: name 'df_convertido' is not defined

# %%
#sin decimales
df_round = df_select.Peso.round(2)
print(df_round)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2515fea7d0b7> in <cell line: 2>()
#       1 #sin decimales
# ----> 2 df_round = df_select.Peso.round(2)
#       3 print(df_round)
#
# NameError: name 'df_select' is not defined

# %%
#EJERCICIO CON DATASET2 PERSONA
#cargar en el notebook los tres dataset de persona
# Especificamos la ruta del dataset en el drive
file_path = "/content/drive/MyDrive/Talento tech 2024/DATASET2.csv"

# Leemos el dataset con la libreria Pandas
df_persona = pd.read_csv(file_path, delimiter = ";")

# Imprimimos el Dataframe
print(df_persona)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-68ac97dc869c> in <cell line: 7>()
#       5
#       6 # Leemos el dataset con la libreria Pandas
# ----> 7 df_persona = pd.read_csv(file_path, delimiter = ";")
#       8
#       9 # Imprimimos el Dataframe
#
# ...

# %%
df_persona.head()
# Out:
#    id weight height  age
# 0   1  143,5    5,3   28
# 1   2  154,2    5,5   45
# 2   3  342,2    5,1   99
# 3   4  144,5    5,5   33
# 4   5  133,2    5,4   54

# %%
#cambiar el nombre de las columnas del df_persona y creamos el dataframe llamado df_nombres
#(weight, height, age, gender)
df_nombres = df_persona.rename(columns={"weight": "Peso", "height": "Altura", "age": "Edad", "gender": "Genero"})
print(df_nombres)
# Out:
#    id   Peso Altura  Edad
# 0   1  143,5    5,3    28
# 1   2  154,2    5,5    45
# 2   3  342,2    5,1    99
# 3   4  144,5    5,5    33
# 4   5  133,2    5,4    54
# 5   6  124,1    5,1    21
# 6   7  129,2    5,3    42

# %%
#EJERCICIO CON DATASET3 PERSONA
#cargar en el notebook los tres dataset de persona
# Especificamos la ruta del dataset en el drive
file_path = "/content/drive/MyDrive/Talento tech 2024/DATASET3.csv"

# Leemos el dataset con la libreria Pandas
df_persona = pd.read_csv(file_path, delimiter = ";")

# Imprimimos el Dataframe
print(df_persona)
# Out:
#    id weight height   age gender  income
# 0   1  143,5    5,6    28      M  100000
# 1   2  167,5    5,4    45      M    none
# 2   3   none    5,2  none   none    none
# 3   4  144,5    5,9    33      M    none
# 4   5  133,2    5,7    54      F    none
# 5   6  124,1    5,2  none      F    none
# 6   7  129,2    5,3    42      M   76000

# %%
df_persona.head()
# Out:
#    id weight height   age gender  income
# 0   1  143,5    5,6    28      M  100000
# 1   2  167,5    5,4    45      M    none
# 2   3   none    5,2  none   none    none
# 3   4  144,5    5,9    33      M    none
# 4   5  133,2    5,7    54      F    none

# %%
#cambiar el nombre de las columnas del df_persona y creamos el dataframe llamado df_nombres
#(weight, height, age, gender)
df_nombres = df_persona.rename(columns={"weight": "Peso", "height": "Altura", "age": "Edad", "gender": "Genero"})
print(df_nombres)
# Out:
#    id   Peso Altura  Edad Genero  income
# 0   1  143,5    5,6    28      M  100000
# 1   2  167,5    5,4    45      M    none
# 2   3   none    5,2  none   none    none
# 3   4  144,5    5,9    33      M    none
# 4   5  133,2    5,7    54      F    none
# 5   6  124,1    5,2  none      F    none
# 6   7  129,2    5,3    42      M   76000
