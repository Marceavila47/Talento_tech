# %% [markdown]
# <a href="https://colab.research.google.com/github/Marceavila47/Talento_tech/blob/main/Laboratorio2_Taller_SQLite_jul15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## INTRODUCCIÓN
# Usaré esta notebook para proporcionar una introducción a SQL, lenguaje imprescindible para todo analista de datos.
#
# Los sistemas gestores de bases de datos interpretan consultas escritas en lenguaje SQL, y así es como interactuamos y obtenemos datos de las bases de datos y aplicaciones.
#
# SQL significa Structured Query Language (Lenguaje de consulta estructurado)
# SQL permite acceder y manipular bases de datos
# SQL es una herramienta simple para el análisis avanzado de datos
# SQL no se usa sólo para manipular datos, sino también para administrar la misma base de datos, crear y modificar el diseño de objetos de la base de datos, como tablas. El elemento de SQL que se usa para crear y modificar objetos de base de datos se denomina lenguaje de definición de datos (DDL). Este curso no trata DDL.
#
# En esta notebook veremos cómo trabajar/manipular tablas. Aprenderemos a usar SQL para interactuar con una base de datos de fútbol europeo y generar información interesante con sus datos.
#
# La base de datos utilizada, pueder ser encontrada [aquí](https://www.kaggle.com/datasets/hugomathien/soccer)
#
# Este ejercicio esta basado en el repositorio de (https://www.kaggle.com/code/gustavojaramillo/data-analysis-using-sql-espa-ol)

# %%
# Importar librerías
import pandas as pd
import sqlite3 # SQLite

# %%
# Lectura
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Los datos de entrada están disponibles en el directorio "drive"
# Se sugiere establecer la conexión con su drive personal

path = "/content/drive/MyDrive/Talento tech 2024/Laboratorio2/database.sqlite"

database = path #+ 'database.sqlite'

# Creamos la conexión con la BD y listaremos las tablas con las que contamos

conn = sqlite3.connect(database)
print ("Conexión exitosa")

print (database)

tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type='table';""", conn)
tables

#Tarea: consultar que el * funcione para dataframe pandas
# Out:
# Conexión exitosa
# /content/drive/MyDrive/Talento tech 2024/Laboratorio2/database.sqlite
#     type               name           tbl_name  rootpage  \
# 0  table    sqlite_sequence    sqlite_sequence         4
# 1  table  Player_Attributes  Player_Attributes        11
# 2  table             Player             Player        14
# 3  table              Match              Match        18
# 4  table             League             League        24
# 5  table            Country            Country        26
# 6  table               Team               Team        29
# 7  table    Team_Attributes    Team_Attributes         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "Player_Attributes" (\n\t`id`\tIN...
# 2  CREATE TABLE `Player` (\n\t`id`\tINTEGER PRIMA...
# 3  CREATE TABLE `Match` (\n\t`id`\tINTEGER PRIMAR...
# 4  CREATE TABLE `League` (\n\t`id`\tINTEGER PRIMA...
# 5  CREATE TABLE `Country` (\n\t`id`\tINTEGER PRIM...
# 6  CREATE TABLE "Team" (\n\t`id`\tINTEGER PRIMARY...
# 7  CREATE TABLE `Team_Attributes` (\n\t`id`\tINTE...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
query = 'SELECT * FROM \'Country\';'

countries = pd.read_sql(query, conn)
countries
# Out:
#        id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland

# %%
#Consulta todas las ligas del futbol europeo
query = """SELECT *
            FROM League; """

#No modificar lo siguiente:
leagues = pd.read_sql(query, conn)
leagues
# Out:
#        id  country_id                      name
# 0       1           1    Belgium Jupiler League
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 3    7809        7809     Germany 1. Bundesliga
# 4   10257       10257             Italy Serie A
# 5   13274       13274    Netherlands Eredivisie
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League

# %%
#Consulta de solo los jugadores unicos de la tabla Player
query = """SELECT DISTINCT player_name
            FROM Player; """

#creo una variable para players_distinct que almacene jugadores unicos
players_distinct = pd.read_sql(query, conn)
players_distinct
# Out:
#                player_name
# 0       Aaron Appindangoye
# 1          Aaron Cresswell
# 2              Aaron Doran
# 3            Aaron Galindo
# 4             Aaron Hughes
# ...                    ...
# 10843       Zoumana Camara
# 10844         Zsolt Laczko
# 10845            Zsolt Low
# 10846  Zurab Khizanishvili
# 10847   Zvjezdan Misimovic
#
# [10848 rows x 1 columns]

# %%
query = """SELECT DISTINCT season
          FROM Match;"""

seasons = pd.read_sql(query, conn)
seasons
# Ls temporadas de analisis son 8, comprendidas entre los años 2008 y 2016
# Out:
#       season
# 0  2008/2009
# 1  2009/2010
# 2  2010/2011
# 3  2011/2012
# 4  2012/2013
# 5  2013/2014
# 6  2014/2015
# 7  2015/2016

# %%
#Listar las temporadas jugadas de esta Base de Datos

query = """SELECT DISTINCT season
FROM Match;"""
seasons = pd.read_sql(query, conn)
seasons
# Out:
#       season
# 0  2008/2009
# 1  2009/2010
# 2  2010/2011
# 3  2011/2012
# 4  2012/2013
# 5  2013/2014
# 6  2014/2015
# 7  2015/2016

# %%
#Ingrese la la consulta SQL entre un par de 3 comillas dobles: """consulta SQL""" después de la palabra query =

query = """SELECT DISTINCT overall_rating
            FROM Player_Attributes;"""


overall_rating = pd.read_sql(query, conn)
overall_rating
# Out:
#     overall_rating
# 0             67.0
# 1             62.0
# 2             61.0
# 3             74.0
# 4             73.0
# ..             ...
# 57            33.0
# 58            36.0
# 59            37.0
# 60            35.0
# 61            94.0
#
# [62 rows x 1 columns]

# %%
query = """
SELECT id, player_name, birthday, height, weight
FROM Player
LIMIT 15;
"""
players = pd.read_sql(query, conn)
players
# Out:
#     id         player_name             birthday  height  weight
# 0    1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 1    2     Aaron Cresswell  1989-12-15 00:00:00  170.18     146
# 2    3         Aaron Doran  1991-05-13 00:00:00  170.18     163
# 3    4       Aaron Galindo  1982-05-08 00:00:00  182.88     198
# 4    5        Aaron Hughes  1979-11-08 00:00:00  182.88     154
# 5    6          Aaron Hunt  1986-09-04 00:00:00  182.88     161
# 6    7          Aaron Kuhl  1996-01-30 00:00:00  172.72     146
# 7    8        Aaron Lennon  1987-04-16 00:00:00  165.10     139
# 8    9        Aaron Lennox  1993-02-19 00:00:00  190.50     181
# 9   10       Aaron Meijers  1987-10-28 00:00:00  175.26     170
# 10  11       Aaron Mokoena  1980-11-25 00:00:00  182.88     181
# 11  12          Aaron Mooy  1990-09-15 00:00:00  175.26     150
# 12  13      Aaron Muirhead  1990-08-30 00:00:00  187.96     168
# 13  14        Aaron Niguez  1989-04-26 00:00:00  170.18     143
# 14  15        Aaron Ramsey  1990-12-26 00:00:00  177.80     154

# %%
#Ingrese la la consulta SQL entre un par de 3 comillas dobles: """consulta SQL""" después de la palabra query =

query = """SELECT *
            FROM Team"""

#No modificar lo siguiente:
teams = pd.read_sql(query, conn)
teams
# Out:
#         id  team_api_id  team_fifa_api_id      team_long_name team_short_name
# 0        1         9987             673.0            KRC Genk             GEN
# 1        2         9993             675.0        Beerschot AC             BAC
# 2        3        10000           15005.0    SV Zulte-Waregem             ZUL
# 3        4         9994            2007.0    Sporting Lokeren             LOK
# 4        5         9984            1750.0   KSV Cercle Brugge             CEB
# ..     ...          ...               ...                 ...             ...
# 294  49479        10190             898.0       FC St. Gallen             GAL
# 295  49837        10191            1715.0             FC Thun             THU
# 296  50201         9777             324.0         Servette FC             SER
# 297  50204         7730            1862.0  FC Lausanne-Sports             LAU
# 298  51606         7896               NaN              Lugano             LUG
#
# [299 rows x 5 columns]

# %%
query = """ SELECT season,
            Country.name                          AS Country,
            League.name                           AS League,
            ROUND(AVG(Match.home_team_goal),2)    AS avg_local_goals,    --Promedio goles locales
            ROUND(AVG(Match.away_team_goal),2)    AS avg_visitor_goals,  --Promedio goles visitantes
            SUM(home_team_goal + away_team_goal)  AS total_goals
        FROM Match
            JOIN Country ON Country.id = Match.country_id
            JOIN League ON League.id = Match.league_id
        WHERE Country.name IN ('Spain', 'France', 'England')
        GROUP BY season, League
        HAVING avg_local_goals BETWEEN 1.4 AND 1.6 AND avg_visitor_goals BETWEEN 1.2 AND 1.6
        ORDER BY season DESC;"""

goals_by_season = pd.read_sql(query, conn)
goals_by_season
# Out:
#       season  Country                  League  avg_local_goals  \
# 0  2015/2016  England  England Premier League             1.49
# 1  2012/2013  England  England Premier League             1.56
# 2  2011/2012  England  England Premier League             1.59
#
#    avg_visitor_goals  total_goals
# 0               1.21         1026
# 1               1.24         1063
# 2               1.22         1066

# %%
query = """
SELECT COUNT(DISTINCT name)
FROM Country;
"""

#No modificar lo siguiente:
count_countries = pd.read_sql(query, conn)
count_countries
# Out:
#    COUNT(DISTINCT name)
# 0                    11

# %%
query = """SELECT stage
            FROM Match;"""

#No modificar lo siguiente:
countdis_stages = pd.read_sql(query, conn)
countdis_stages
# Out:
#        stage
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 25974      9
# 25975      9
# 25976      9
# 25977      9
# 25978      9
#
# [25979 rows x 1 columns]

# %%
#Traer el número de etapas jugadas de la tabla Match
query = """SELECT stage
            FROM Match;"""

#No modificar lo siguiente:
countdis_stages = pd.read_sql(query, conn)
countdis_stages
# Out:
#        stage
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 25974      9
# 25975      9
# 25976      9
# 25977      9
# 25978      9
#
# [25979 rows x 1 columns]

# %%
#Traer la suma de goles hechos por los equipos visitantes de la tabla Match
query = """SELECT away_team_goal
            FROM Match;"""

#No modificar lo siguiente:
sum_awayteam = pd.read_sql(query, conn)
sum_awayteam
# Out:
#        away_team_goal
# 0                   1
# 1                   0
# 2                   3
# 3                   0
# 4                   3
# ...               ...
# 25974               0
# 25975               2
# 25976               0
# 25977               0
# 25978               3
#
# [25979 rows x 1 columns]

# %%
#raer el promedio de goles hechos por los equipos locales y el promedio de goles hechos por los visitantes de la tabla Match¶
query = """SELECT avg(home_team_goal), avg(away_team_goal)
            FROM Match;"""
#No modificar lo siguiente:
avg_teamgoals = pd.read_sql(query, conn)
avg_teamgoals
# Out:
#    avg(home_team_goal)  avg(away_team_goal)
# 0             1.544594             1.160938

# %%
#Traer la máxima cantidad de goles que un equipo visitante anotó en los juegos de la tabla Match¶
query = """Select max(away_team_goal)
            FROM Match;"""

#No modificar lo siguiente:
max_teamgoals = pd.read_sql(query, conn)
max_teamgoals
# Out:
#    max(away_team_goal)
# 0                    9

# %%
#Traer el promedio de goles por partido de la tabla Match
query = """SELECT avg(home_team_goal + away_team_goal)
            FROM Match;"""

#No modificar lo siguiente:
avg_sum_goals = pd.read_sql(query, conn)
avg_sum_goals
# Out:
#    avg(home_team_goal + away_team_goal)
# 0                              2.705531

# %%
# Listar los jugadores que pesan 165 libras
query = """SELECT id, player_name, birthday, height, weight
        FROM Player
        WHERE weight = 165
        LIMIT 15;"""

players_weight = pd.read_sql(query, conn)
players_weight
# Out:
#      id          player_name             birthday  height  weight
# 0    27   Abdelmalek Cherrad  1981-01-14 00:00:00  185.42     165
# 1    44   Abdoulaye Doucoure  1993-01-01 00:00:00  182.88     165
# 2    46      Abdoulaye Keita  1994-01-05 00:00:00  175.26     165
# 3    49  Abdoulwahid Sissoko  1990-03-20 00:00:00  182.88     165
# 4    58   Abdullah Al Hafith  1992-12-25 00:00:00  187.96     165
# 5    62           Abel Gomez  1982-02-20 00:00:00  182.88     165
# 6    67                 Abel  1978-12-22 00:00:00  177.80     165
# 7    69         Abiola Dauda  1988-02-03 00:00:00  180.34     165
# 8    78     Abraham Paz Cruz  1979-03-14 00:00:00  177.80     165
# 9    84          Aco Stojkov  1983-04-29 00:00:00  177.80     165
# 10  110            Adam King  1995-10-11 00:00:00  180.34     165
# 11  119       Adam Matuschyk  1989-02-14 00:00:00  180.34     165
# 12  132            Adam Vass  1988-09-09 00:00:00  180.34     165
# 13  157        Adnan Januzaj  1995-02-05 00:00:00  182.88     165
# 14  169   Adrian Klepczynski  1981-04-01 00:00:00  187.96     165

# %%
# Listar las temporadas en que un equipo visitante anotó 7 o más goles
query = """SELECT (season, home_team_goal, away_team_goal)
            FROM Match
            WHERE away_team_goal >= 7;"""

#No modificar lo siguiente:
away_team_goals = pd.read_sql(query, conn)
away_team_goals
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2201         try:
# -> 2202             cur.execute(sql, *args)
#    2203             return cur
#
# OperationalError: row value misused
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-27-df45bb4ec03b> in <cell line: 7>()
#       5
#       6 #No modificar lo siguiente:
# ----> 7 away_team_goals = pd.read_sql(query, conn)
#       8 away_team_goals
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     633     with pandasSQL_builder(con) as pandas_sql:
#     634         if isinstance(pandas_sql, SQLiteDatabase):
# --> 635             return pandas_sql.read_query(
#     636                 sql,
#     637                 index_col=index_col,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2264         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2265     ) -> DataFrame | Iterator[DataFrame]:
# -> 2266         cursor = self.execute(sql, params)
#    2267         columns = [col_desc[0] for col_desc in cursor.description]
#    2268
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2212
#    2213             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2214             raise ex from exc
#    2215
#    2216     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT (season, home_team_goal, away_team_goal)
#             FROM Match
#             WHERE away_team_goal >= 7;': row value misused

# %%
#Traer el Id de los equipos que desarrollan un dribbling normal y su velocidad de juego es balanceada
query = """Select (id, buildUpPlaySpeed, buildUpPlayDribbling)
            FROM Team_Attributes
            WHERE buildUpPlaySpeed = 'Balanced' AND buildUpPlayDribbling = 'Normal';"""

#No modificar lo siguiente:
team_att_and = pd.read_sql(query, conn)
team_att_and
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2201         try:
# -> 2202             cur.execute(sql, *args)
#    2203             return cur
#
# OperationalError: row value misused
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-28-7ae7bf5e0b8b> in <cell line: 7>()
#       5
#       6 #No modificar lo siguiente:
# ----> 7 team_att_and = pd.read_sql(query, conn)
#       8 team_att_and
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     633     with pandasSQL_builder(con) as pandas_sql:
#     634         if isinstance(pandas_sql, SQLiteDatabase):
# --> 635             return pandas_sql.read_query(
#     636                 sql,
#     637                 index_col=index_col,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2264         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2265     ) -> DataFrame | Iterator[DataFrame]:
# -> 2266         cursor = self.execute(sql, params)
#    2267         columns = [col_desc[0] for col_desc in cursor.description]
#    2268
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2212
#    2213             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2214             raise ex from exc
#    2215
#    2216     @staticmethod
#
# DatabaseError: Execution failed on sql 'Select (id, buildUpPlaySpeed, buildUpPlayDribbling)
#             FROM Team_Attributes
#             WHERE buildUpPlaySpeed = 'Balanced' AND buildUpPlayDribbling = 'Normal';': row value misused

# %%
#Traer el Id de los equipos que desarrollan un juego de pase largo o su velocidad de juego es rápida

query = """Select (id, buildUpPlaySpeed, buildUpPlayPassing,buildUpPlaySpeedClass)
            FROM Team_Attributes
            WHERE buildUpPlayPassing = 'Long' OR buildUpPlaySpeed = 'Fast';"""

#No modificar lo siguiente:
team_att_or = pd.read_sql(query, conn)
team_att_or
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2201         try:
# -> 2202             cur.execute(sql, *args)
#    2203             return cur
#
# OperationalError: row value misused
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-29-64c1f07768a3> in <cell line: 8>()
#       6
#       7 #No modificar lo siguiente:
# ----> 8 team_att_or = pd.read_sql(query, conn)
#       9 team_att_or
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     633     with pandasSQL_builder(con) as pandas_sql:
#     634         if isinstance(pandas_sql, SQLiteDatabase):
# --> 635             return pandas_sql.read_query(
#     636                 sql,
#     637                 index_col=index_col,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2264         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2265     ) -> DataFrame | Iterator[DataFrame]:
# -> 2266         cursor = self.execute(sql, params)
#    2267         columns = [col_desc[0] for col_desc in cursor.description]
#    2268
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2212
#    2213             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2214             raise ex from exc
#    2215
#    2216     @staticmethod
#
# DatabaseError: Execution failed on sql 'Select (id, buildUpPlaySpeed, buildUpPlayPassing,buildUpPlaySpeedClass)
#             FROM Team_Attributes
#             WHERE buildUpPlayPassing = 'Long' OR buildUpPlaySpeed = 'Fast';': row value misused

# %%
#Traer la tabla de países sin Bélgica

query = """Select Country.name
            FROM Country
            WHERE NOT Country.name = 'Belgium';"""

#No modificar lo siguiente:
countries_not = pd.read_sql(query, conn)
countries_not
# Out:
#           name
# 0      England
# 1       France
# 2      Germany
# 3        Italy
# 4  Netherlands
# 5       Poland
# 6     Portugal
# 7     Scotland
# 8        Spain
# 9  Switzerland

# %%
#6.4.1 Práctica: Traer la tabla de países únicamente con Italia
query = """Select Country.name
            FROM Country
            WHERE Country.name = 'Italy';"""

#No modificar lo siguiente:
countries_italy = pd.read_sql(query, conn)
countries_italy
# Out:
#     name
# 0  Italy

# %%
#6.4.2 Práctica: Traer la tabla de países sin Polonia
query = """Select Country.name
            FROM Country
            WHERE Country.name != 'Poland';"""

#No modificar lo siguiente:
countries_not_poland = pd.read_sql(query, conn)
countries_not_poland
# Out:
#           name
# 0      Belgium
# 1      England
# 2       France
# 3      Germany
# 4        Italy
# 5  Netherlands
# 6     Portugal
# 7     Scotland
# 8        Spain
# 9  Switzerland

# %%
# 6.4.3 Práctica: Listar los jugadores que pesen entre 174 y 176 libras
query = """SELECT id, player_name, birthday, height, weight
        FROM Player
        WHERE weight BETWEEN 174 AND 176
        LIMIT 15;"""

players_weight = pd.read_sql(query, conn)
players_weight
# Out:
#      id            player_name             birthday  height  weight
# 0    17  Aaron Taylor-Sinclair  1991-04-08 00:00:00  182.88     176
# 1    34           Abdou Traore  1988-01-17 00:00:00  180.34     174
# 2    39           Abdoulaye Ba  1991-01-01 00:00:00  198.12     174
# 3    43       Abdoulaye Diallo  1992-03-30 00:00:00  187.96     174
# 4    61           Abel Aguilar  1985-01-06 00:00:00  185.42     176
# 5    68     Abella Perez Damia  1982-04-15 00:00:00  187.96     174
# 6    74       Abraham Gonzalez  1985-07-16 00:00:00  177.80     176
# 7    79          Achille Coser  1982-07-14 00:00:00  185.42     174
# 8    89             Adam Banas  1982-12-25 00:00:00  185.42     174
# 9    90            Adam Bodzek  1985-09-07 00:00:00  182.88     174
# 10  102          Adam Dzwigala  1995-09-25 00:00:00  185.42     176
# 11  133       Adam Waszkiewicz  1993-12-06 00:00:00  182.88     174
# 12  136         Adama Francois  1989-11-30 00:00:00  193.04     176
# 13  153         Admir Aganovic  1986-08-25 00:00:00  182.88     176
# 14  154          Admir Mehmedi  1991-03-16 00:00:00  182.88     176

# %%
#6.4.4 Práctica: Listar a los Messi de la base de datos de jugadores
query = """SELECT id, player_name, birthday, height, weight
        FROM Player
        WHERE player_name = 'Lionel Messi'
        LIMIT 15;"""

players_messi = pd.read_sql(query, conn)
players_messi
# Out:
#      id   player_name             birthday  height  weight
# 0  6176  Lionel Messi  1987-06-24 00:00:00  170.18     159

# %%
#7.1.1 Ejemplo: Listar a los equipos y ordenarlos por nombre
query = """SELECT id, team_long_name AS team_name
            FROM Team
            ORDER BY team_long_name ASC
            LIMIT 250;"""
#No modificar lo siguiente:
teams_orderby = pd.read_sql(query, conn)
teams_orderby
# Out:
#         id             team_name
# 0    16848  1. FC Kaiserslautern
# 1    15624            1. FC Köln
# 2    16239        1. FC Nürnberg
# 3    16243       1. FSV Mainz 05
# 4    11817            AC Ajaccio
# ..     ...                   ...
# 245   6504           Southampton
# 246  18079  SpVgg Greuther Fürth
# 247  26559      Sparta Rotterdam
# 248  35285           Sporting CP
# 249     18    Sporting Charleroi
#
# [250 rows x 2 columns]

# %%
# 7.1.2 Listar la tabla de países en orden descendente
query = """SELECT name
            FROM Country
            ORDER BY name DESC;"""

#No modificar lo siguiente:
countries_orderby = pd.read_sql(query, conn)
countries_orderby
# Out:
#            name
# 0   Switzerland
# 1         Spain
# 2      Scotland
# 3      Portugal
# 4        Poland
# 5   Netherlands
# 6         Italy
# 7       Germany
# 8        France
# 9       England
# 10      Belgium

# %%
#7.1.3 Listar el id de los 15 jugadores con menos peso
query = """SELECT id, player_name, birthday, height, weight
        FROM Player
        ORDER BY weight ASC
        LIMIT 15;"""

players_weightasc = pd.read_sql(query, conn)
players_weightasc
# Out:
#        id            player_name             birthday  height  weight
# 0    5453             Juan Quero  1984-10-17 00:00:00  157.48     117
# 1    6853        Mariusz Rybicki  1993-03-13 00:00:00  175.26     121
# 2   10954        Yohandry Orozco  1991-03-19 00:00:00  165.10     121
# 3    1480                Caetano  1991-04-20 00:00:00  165.10     123
# 4    2612       Diego Buonanotte  1988-04-19 00:00:00  160.02     123
# 5     317            Aldo Kalulu  1996-01-21 00:00:00  165.10     126
# 6     655            Andre Horta  1996-11-07 00:00:00  167.64     126
# 7    3446           Fouad Rachid  1991-11-15 00:00:00  162.56     126
# 8    7258           Maxi Moralez  1987-02-27 00:00:00  160.02     126
# 9    7264           Maxime Blanc  1992-01-23 00:00:00  165.10     126
# 10   1111        Barry Nicholson  1978-08-24 00:00:00  170.18     128
# 11   1824  Christopher Teichmann  1995-10-13 00:00:00  177.80     128
# 12   3997        Gregory Lacombe  1982-01-11 00:00:00  165.10     128
# 13   4316          Ibrahim Rabiu  1991-03-15 00:00:00  167.64     128
# 14   5869            Koki Mizuno  1985-09-06 00:00:00  172.72     128

# %%
#7.1.4 Práctica: Listar el id de los 10 jugadores con mayor estatura
query = """SELECT id, player_name,height
        FROM Player
        ORDER BY height DESC
        LIMIT 10;"""

players_heightdesc = pd.read_sql(query, conn)
players_heightdesc
# Out:
#      id        player_name  height
# 0  5908   Kristof van Hout  208.28
# 1  1301       Bogdan Milic  203.20
# 2  1926  Costel Pantilimon  203.20
# 3  3274       Fejsal Mulic  203.20
# 4  5568      Jurgen Wevers  203.20
# 5  5804         Kevin Vink  203.20
# 6  5957      Lacina Traore  203.20
# 7  8016       Nikola Zigic  203.20
# 8  8285      Paolo Acerbis  203.20
# 9  8638      Pietro Marino  203.20

# %%
#7.1.5 Listar el id de los 10 jugadores con mayor estatura y ordenarlos alfabéticamente pero de forma descendente
query = """SELECT id, player_name,height
        FROM Player
        ORDER BY height DESC, player_name ASC
        LIMIT 10;"""

players_height = pd.read_sql(query, conn)
players_height
# Out:
#      id        player_name  height
# 0  5908   Kristof van Hout  208.28
# 1  1301       Bogdan Milic  203.20
# 2  1926  Costel Pantilimon  203.20
# 3  3274       Fejsal Mulic  203.20
# 4  5568      Jurgen Wevers  203.20
# 5  5804         Kevin Vink  203.20
# 6  5957      Lacina Traore  203.20
# 7  8016       Nikola Zigic  203.20
# 8  8285      Paolo Acerbis  203.20
# 9  8638      Pietro Marino  203.20

# %%
# 8.1.1  Queremos conocer cuántos equipos tienen cada tipo de velocidad de juego
query = """SELECT buildUpPlaySpeedClass, COUNT(id)
            FROM Team_Attributes
            GROUP BY buildUpPlaySpeedClass;"""
teams_speed = pd.read_sql(query, conn)
teams_speed
# Out:
#   buildUpPlaySpeedClass  COUNT(id)
# 0              Balanced       1184
# 1                  Fast        172
# 2                  Slow        102

# %%
#8.1.2 Práctica: Queremos conocer cuántos equipos tienen cada clase de juego defensivo
query = """SELECT DefensePressureClass = 'Medium', DefensePressureClass = 'Deep', DefensePressureClass = 'High' , COUNT(id)
            FROM Team_Attributes
            GROUP BY buildUpPlayDribblingClass;"""
teams_dribbling = pd.read_sql(query, conn)
teams_dribbling
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2201         try:
# -> 2202             cur.execute(sql, *args)
#    2203             return cur
#
# OperationalError: no such column: DefensePressureClass
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-43-1508ecc4bbda> in <cell line: 5>()
#       3             FROM Team_Attributes
#       4             GROUP BY buildUpPlayDribblingClass;"""
# ----> 5 teams_dribbling = pd.read_sql(query, conn)
#       6 teams_dribbling
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     633     with pandasSQL_builder(con) as pandas_sql:
#     634         if isinstance(pandas_sql, SQLiteDatabase):
# --> 635             return pandas_sql.read_query(
#     636                 sql,
#     637                 index_col=index_col,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2264         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2265     ) -> DataFrame | Iterator[DataFrame]:
# -> 2266         cursor = self.execute(sql, params)
#    2267         columns = [col_desc[0] for col_desc in cursor.description]
#    2268
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2212
#    2213             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2214             raise ex from exc
#    2215
#    2216     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT DefensePressureClass = 'Medium', DefensePressureClass = 'Deep', DefensePressureClass = 'High' , COUNT(id)
#             FROM Team_Attributes
#             GROUP BY buildUpPlayDribblingClass;': no such column: DefensePressureClass

# %%
#8.1.3 Práctica: Analítica básica de las temporadas
query = """SELECT stage AS number_of_stages, AVG(home_team_goal) AS avg_home_team_goals, AVG(away_team_goal) AS avg_away_team_goals
            FROM Match
            where (home_team_goal + away_team_goal) > 7
            GROUP BY season;"""
matches_season = pd.read_sql(query, conn)
matches_season
# Out:
#    number_of_stages  avg_home_team_goals  avg_away_team_goals
# 0                 9             4.666667             3.388889
# 1                13             5.521739             3.000000
# 2                16             4.576923             3.769231
# 3                12             4.657143             3.628571
# 4                16             4.392857             4.000000
# 5                16             4.375000             3.875000
# 6                22             4.464286             3.964286
# 7                 6             4.888889             3.666667

# %%
#9.1 Tipos de JOIN
#9.2.1 Ejemplo: Lista de ligas y su país
query = """SELECT L.id AS Id_League, L.name AS Nombre_League, C.name AS Pais
        FROM League AS L
        JOIN Country AS C ON C.id = L.country_id;"""

country_leagues = pd.read_sql(query, conn)
country_leagues
# Out:
#     Id_League             Nombre_League         Pais
# 0           1    Belgium Jupiler League      Belgium
# 1        1729    England Premier League      England
# 2        4769            France Ligue 1       France
# 3        7809     Germany 1. Bundesliga      Germany
# 4       10257             Italy Serie A        Italy
# 5       13274    Netherlands Eredivisie  Netherlands
# 6       15722        Poland Ekstraklasa       Poland
# 7       17642  Portugal Liga ZON Sagres     Portugal
# 8       19694   Scotland Premier League     Scotland
# 9       21518           Spain LIGA BBVA        Spain
# 10      24558  Switzerland Super League  Switzerland

# %%
#9.2.2 Práctica: Comparación de cantidad de partidos jugados en cierta temporada de España y Bélgica
query =

country_matches = pd.read_sql(query, conn)
country_matches
# Out:
#   File "<ipython-input-46-836fc2b70b3d>", line 2
#     query =
#            ^
# SyntaxError: invalid syntax

# %%
from typing import Match
#9.2.3 Práctica: Lista detallada de juegos

query = """Select id, country.name AS country_name, league.name AS league_name, stage, season, date, home_team_goal, away_team_goal, team_long_name AS home_team, team_long_name AS away_team
            FROM Match
JOIN Country ON Country.id = Match.country_id \
            JOIN League ON League.id = Match.league_id \
            JOIN Team ON Team.team_api_id = Match.home_team_api_id \
            JOIN Team ON Team.team_api_id = Match.away_team_api_id;"""
# no modificar lo siguiente
detailed_matches = pd.read_sql(query, conn)
detailed_matches
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2201         try:
# -> 2202             cur.execute(sql, *args)
#    2203             return cur
#
# OperationalError: ambiguous column name: id
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-53-ea5f4798ccfa> in <cell line: 11>()
#       9             JOIN Team ON Team.team_api_id = Match.away_team_api_id;"""
#      10 # no modificar lo siguiente
# ---> 11 detailed_matches = pd.read_sql(query, conn)
#      12 detailed_matches
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     633     with pandasSQL_builder(con) as pandas_sql:
#     634         if isinstance(pandas_sql, SQLiteDatabase):
# --> 635             return pandas_sql.read_query(
#     636                 sql,
#     637                 index_col=index_col,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2264         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2265     ) -> DataFrame | Iterator[DataFrame]:
# -> 2266         cursor = self.execute(sql, params)
#    2267         columns = [col_desc[0] for col_desc in cursor.description]
#    2268
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2212
#    2213             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2214             raise ex from exc
#    2215
#    2216     @staticmethod
#
# DatabaseError: Execution failed on sql 'Select id, country.name AS country_name, league.name AS league_name, stage, season, date, home_team_goal, away_team_goal, team_long_name AS home_team, team_long_name AS away_team
#             FROM Match
# JOIN Country ON Country.id = Match.country_id             JOIN League ON League.id = Match.league_id             JOIN Team ON Team.team_api_id = Match.home_team_api_id             JOIN Team ON Team.team_api_id = Match.away_team_api_id;': ambiguous column name: id

# %%
#10.1.1 Ejemplo: Análisis de goles por temporada en las ligas de España, Francia e Inglaterra
query = """SELECT season,
            Country.name AS Country,
            League.name AS League,
            ROUND(AVG(Match.home_team_goal),2) AS avg_local_goals,
            ROUND(AVG(Match.away_team_goal),2) AS avg_visitor_goals,
            SUM(home_team_goal+away_team_goal) AS total_goals
        FROM Match
        JOIN Country ON Country.id = Match.country_id
        JOIN League ON League.id = Match.league_id
        WHERE Country.name IN ('Spain', 'France', 'England')
        GROUP BY season, League
        HAVING avg_local_goals BETWEEN 1.4 AND 1.6 AND avg_visitor_goals BETWEEN 1.2 AND 1.6
        ORDER BY season DESC;"""

goals_by_season = pd.read_sql(query, conn)
goals_by_season
# Out:
#       season  Country                  League  avg_local_goals  \
# 0  2015/2016  England  England Premier League             1.49
# 1  2012/2013  England  England Premier League             1.56
# 2  2011/2012  England  England Premier League             1.59
#
#    avg_visitor_goals  total_goals
# 0               1.21         1026
# 1               1.24         1063
# 2               1.22         1066

# %%
#10.1.2 Práctica: Nos basaremos en ejemplo "Lista detallada de juegos", pero eliminaremos la información del partido y fechas, para comparar las ligas por temporadas
query ="""SELECT
    l.name AS league_name,
    m.season AS season,
    AVG(m.home_team_goal + m.away_team_goal) AS avg_goals_per_match
FROM
    Match m
JOIN
    Country c ON m.country_id = c.id
JOIN
    League l ON m.league_id = l.id
WHERE
    c.name IN ('Spain', 'Germany', 'France', 'Italy', 'England')
GROUP BY
    l.name, m.season
HAVING
    AVG(m.home_team_goal + m.away_team_goal) > 2.5
ORDER BY
    avg_goals_per_match DESC;"""


#No modificar lo siguiente:
leages_by_season = pd.read_sql(query, conn)
leages_by_season
# Out:
#                league_name     season  avg_goals_per_match
# 0    Germany 1. Bundesliga  2013/2014             3.160131
# 1    Germany 1. Bundesliga  2012/2013             2.934641
# 2    Germany 1. Bundesliga  2008/2009             2.921569
# 3    Germany 1. Bundesliga  2010/2011             2.921569
# 4          Spain LIGA BBVA  2008/2009             2.897368
# 5          Spain LIGA BBVA  2012/2013             2.871053
# 6    Germany 1. Bundesliga  2011/2012             2.859477
# 7    Germany 1. Bundesliga  2009/2010             2.830065
# 8    Germany 1. Bundesliga  2015/2016             2.830065
# 9   England Premier League  2011/2012             2.805263
# 10  England Premier League  2010/2011             2.797368
# 11  England Premier League  2012/2013             2.797368
# 12  England Premier League  2009/2010             2.771053
# 13  England Premier League  2013/2014             2.768421
# 14         Spain LIGA BBVA  2011/2012             2.763158
# 15   Germany 1. Bundesliga  2014/2015             2.754902
# 16         Spain LIGA BBVA  2013/2014             2.750000
# 17         Spain LIGA BBVA  2015/2016             2.744737
# 18         Spain LIGA BBVA  2010/2011             2.742105
# 19           Italy Serie A  2013/2014             2.723684
# 20         Spain LIGA BBVA  2009/2010             2.713158
# 21  England Premier League  2015/2016             2.700000
# 22           Italy Serie A  2014/2015             2.686016
# 23         Spain LIGA BBVA  2014/2015             2.655263
# 24           Italy Serie A  2012/2013             2.639474
# 25           Italy Serie A  2009/2010             2.610526
# 26           Italy Serie A  2008/2009             2.600000
# 27           Italy Serie A  2011/2012             2.583799
# 28           Italy Serie A  2015/2016             2.576316
# 29  England Premier League  2014/2015             2.565789
# 30          France Ligue 1  2012/2013             2.544737
# 31          France Ligue 1  2015/2016             2.526316
# 32          France Ligue 1  2011/2012             2.515789
# 33           Italy Serie A  2010/2011             2.513158

# %%
#10.1.3 Práctica: Análisis sobre los equipos que más goles realizaron jugando como locales
query = """

teams_by_season = pd.read_sql(query, conn)
teams_by_season
# Out:
#   File "<ipython-input-55-621389ee193a>", line 2
#     query = """
#             ^
# SyntaxError: incomplete input

# %%
#10.1.4 Práctica: Análisis del cambio en overall rating y potential de Cristiano Ronaldo por edad.
query =""" SELECT player_name, overall_rating, potential, date AS RatingDate
FROM Player_Attributes,Player
WHERE player_name = 'Cristiano Ronaldo'
 ;"""


#No modificar lo siguiente:
ratingCristiano = pd.read_sql(query, conn)
ratingCristiano
# Out:
#               player_name  overall_rating  potential           RatingDate
# 0       Cristiano Ronaldo            67.0       71.0  2016-02-18 00:00:00
# 1       Cristiano Ronaldo            67.0       71.0  2015-11-19 00:00:00
# 2       Cristiano Ronaldo            62.0       66.0  2015-09-21 00:00:00
# 3       Cristiano Ronaldo            61.0       65.0  2015-03-20 00:00:00
# 4       Cristiano Ronaldo            61.0       65.0  2007-02-22 00:00:00
# ...                   ...             ...        ...                  ...
# 183973  Cristiano Ronaldo            83.0       85.0  2009-08-30 00:00:00
# 183974  Cristiano Ronaldo            78.0       80.0  2009-02-22 00:00:00
# 183975  Cristiano Ronaldo            77.0       80.0  2008-08-30 00:00:00
# 183976  Cristiano Ronaldo            78.0       81.0  2007-08-30 00:00:00
# 183977  Cristiano Ronaldo            80.0       81.0  2007-02-22 00:00:00
#
# [183978 rows x 4 columns]

# %%
#12.1 Ejemplo: Queremos una tabla que me indique los partidos jugados por el FC Barcelona, su rival, la fecha de juego y si perdió, ganó o empato
query= """SELECT DATE(Match.date) as MatchDate,
                Home.team_long_name AS  HomeTeam,
                home_team_goal AS Home_goals,
                Visitor.team_long_name AS VisitorTeam,
                away_team_goal Visitor_goals,
                CASE
                    WHEN Home.team_api_id = 8634 AND home_team_goal < away_team_goal THEN 'Barca lost :('
                    WHEN Home.team_api_id = 8634 AND home_team_goal > away_team_goal THEN 'Barca won'
                    WHEN Visitor.team_api_id = 8634 AND home_team_goal < away_team_goal THEN 'Barca won'
                    WHEN Visitor.team_api_id = 8634 AND home_team_goal > away_team_goal THEN 'Barca lost :('
                    ELSE 'Tie'
                END AS Outcome
        FROM Match
        LEFT JOIN Team AS Home on Home.team_api_id = Match.home_team_api_id
        LEFT JOIN Team AS Visitor on Visitor.team_api_id = Match.away_team_api_id
        WHERE (Visitor.team_api_id = 8634 OR Home.team_api_id = 8634) AND season = "2012/2013"
        Order by MatchDate DESC
        LIMIT 15;"""

Barca_results = pd.read_sql(query, conn)
Barca_results
# Out:
#      MatchDate                 HomeTeam  Home_goals  \
# 0   2013-06-01             FC Barcelona           4
# 1   2013-05-26             RCD Espanyol           0
# 2   2013-05-19             FC Barcelona           2
# 3   2013-05-12          Atlético Madrid           1
# 4   2013-05-05             FC Barcelona           4
# 5   2013-04-27  Athletic Club de Bilbao           2
# 6   2013-04-20             FC Barcelona           1
# 7   2013-04-14            Real Zaragoza           0
# 8   2013-04-06             FC Barcelona           5
# 9   2013-03-30         RC Celta de Vigo           2
# 10  2013-03-17             FC Barcelona           3
# 11  2013-03-09             FC Barcelona           2
# 12  2013-03-02           Real Madrid CF           2
# 13  2013-02-23             FC Barcelona           2
# 14  2013-02-16               Granada CF           1
#
#                   VisitorTeam  Visitor_goals        Outcome
# 0                   Málaga CF              1      Barca won
# 1                FC Barcelona              2      Barca won
# 2             Real Valladolid              1      Barca won
# 3                FC Barcelona              2      Barca won
# 4         Real Betis Balompié              2      Barca won
# 5                FC Barcelona              2            Tie
# 6                  Levante UD              0      Barca won
# 7                FC Barcelona              3      Barca won
# 8                RCD Mallorca              0      Barca won
# 9                FC Barcelona              2            Tie
# 10             Rayo Vallecano              1      Barca won
# 11  RC Deportivo de La Coruña              0      Barca won
# 12               FC Barcelona              1  Barca lost :(
# 13                 Sevilla FC              1      Barca won
# 14               FC Barcelona              2      Barca won

# %%
#12.2 Práctica: Queremos una tabla que me indique los partidos jugados por el FC Barcelona como local contra el Real Madrid CF, la fecha de juego y si perdió, ganó o empató.
query = """SELECT
    date AS fecha_de_juego,
    CASE
"""
        WHEN home_team_goal > away_team_goal THEN 'Won'
        WHEN home_team_goal < away_team_goal THEN 'Lost'
        ELSE 'Tie'
    END AS Results
FROM
    Match
WHERE
    (home_team_api_id = (SELECT team_api_id FROM Team WHERE team_long_name = 'FC Barcelona'))
    AND
    (away_team_api_id = (SELECT team_api_id FROM Team WHERE team_long_name = 'Real Madrid CF'))
ORDER BY
    date;

BarcaMadrid_results = pd.read_sql(query, conn)
BarcaMadrid_results
# Out:
#   File "<tokenize>", line 9
#     END AS Results
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
#13.1 Ejemplo: Rating de Cristiano Ronaldo y Lionel Messi versus los demás jugadores.
query = """SELECT CASE
                   WHEN player_name = 'Cristiano Ronaldo' THEN 'Cristiano Ronaldo'
                   WHEN player_name = 'Lionel Messi' THEN 'Lionel Messi'
                   ELSE 'Others'
                   END AS Player,
           PA_Grouped.avg_overall_rating AS avg_overall_rating,
           PA_Grouped.avg_potential AS avg_potential
           FROM Player
           LEFT JOIN
                    (SELECT Player_Attributes.player_api_id,
                         ROUND(avg(Player_Attributes.overall_rating),2) AS avg_overall_rating,
                         ROUND(avg(Player_Attributes.potential),2) AS avg_potential
                     FROM Player_Attributes
                     GROUP BY Player_Attributes.player_api_id)
                    AS PA_Grouped
           ON Player.player_api_id = PA_Grouped.player_api_id
           GROUP BY Player
           ORDER BY Player;"""

players_rating = pd.read_sql(query, conn)
players_rating
# Out:
#               Player  avg_overall_rating  avg_potential
# 0  Cristiano Ronaldo               91.28          93.48
# 1       Lionel Messi               92.19          95.23
# 2             Others               63.60          67.60

# %%
#13.2 Práctica: Comparación de tipo de juego entre el FC Barcelona y Real Madrid FC - SUB QUERY
SELECT
  ta.date AS RatingDate,
  ta.team_api_id AS TeamID,
  t.team_long_name AS Team,
    CASE
        WHEN ta.buildUpPlayDribbling >= 70 THEN 'Long'
        WHEN ta.buildUpPlayDribbling <= 30 THEN 'Short'
        ELSE 'Mixed'
    END AS Dribbling
    -- Clasificación para buildUpPlaySpeed
    CASE
        WHEN ta.buildUpPlaySpeed >= 70 THEN 'Fast'
        WHEN ta.buildUpPlaySpeed <= 30 THEN 'Slow'
        ELSE 'Balanced'
    END AS PlaySpeed,
    -- Clasificación para buildUpPlayPassing
    CASE
        WHEN ta.buildUpPlayPassing >= 70 THEN 'Long'
        WHEN ta.buildUpPlayPassing <= 30 THEN 'Short'
        ELSE 'Mixed'
    END AS PlayPassing,
    -- Clasificación para chanceCreationShooting
    CASE
        WHEN ta.chanceCreationShooting >= 68 THEN 'Lots'
        WHEN ta.chanceCreationShooting <= 30 THEN 'Little'
        ELSE 'Normal'
    END AS CreationShooting
FROM
    Team_Attributes ta
JOIN
    Team t ON ta.team_api_id = t.team_api_id
ORDER BY
    RatingDate, TeamID;
# Out:
#   File "<ipython-input-69-bcdf8c80b026>", line 3
#     ta.date AS RatingDate,
#     ^
# IndentationError: unexpected indent

# %%
#13.3 Práctica: Comparación de tipo de juego entre el FC Barcelona y Real Madrid FC - WHERE
query=



#No modificar lo siguiente:

subquery2 = pd.read_sql(query, conn)
subquery2
