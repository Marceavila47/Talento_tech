# %% [markdown]
# <a href="https://colab.research.google.com/github/Marceavila47/Talento_tech/blob/main/Proyecto_importaciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel('/content/05_Importaciones_2024_Mayo_edited.xlsx')
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-307c18bc0917> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df = pd.read_excel('/content/05_Importaciones_2024_Mayo_edited.xlsx')
#       3 df.head()
#       4
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     515
#     516     try:
# --> 517         data = io.parse(
#     518             sheet_name=sheet_name,
#     519             header=header,
#
# ...

# %%
import pandas as pd
excel_data_df = pandas.read_excel('/content/05_Importaciones_2024_Mayo_edited.xlsx')
excel_data_df.head()
# Out:
#    BANC_CODIGO_BANCO  COD_ADUANA_PRESENTADA  ADUANA_PRESENTADA  \
# 0                  7                      3  Aduanas de Bogota
# 1                 13                      3  Aduanas de Bogota
# 2                 13                      3  Aduanas de Bogota
# 3                 13                      3  Aduanas de Bogota
# 4                 13                      3  Aduanas de Bogota
#
#    CODIGO_SUCURSAL  CODIGO_CAJERO  CONSECUTIVO_CAJERO  \
# 0              237             26              475985
# 1              346              2               13666
# 2              346              2               13667
# 3              346              2               13663
# 4              346              2               13636
#
#    DIGITO_VERIFICACION_DOC CODIGO_MODALIDAD_DECLARAC  COD_TIPO_DECLARACION  \
# 0                        1                       NaN                     3
# 1                        2                       NaN                     1
# ...
