# %% [markdown]
# <a href="https://colab.research.google.com/github/Marceavila47/Talento_tech/blob/main/Ejercicio_Esperanza_de_vida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar librerías
import pandas as pd
import sqlite3 # SQLite

# %%
# Lectura
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/MyDrive/Talento tech 2024/Laboratorio2/ejercicio esperanza de vida.xlsx"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pd.read_excel(path)
# Out:
#     año  Esperanza de vida
# 0  1920              55.38
# 1  1930              59.57
# 2  1940              63.24
# 3  1950              68.07
# 4  1960              69.86
# 5  1970              70.86
# 6  1980              73.91
# 7  1990              75.40
# 8  2000              76.90
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['año'].plot(kind='hist', bins=20, title='año')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Esperanza de vida'].plot(kind='hist', bins=20, title='Esperanza de vida')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
_df_6['Esperanza de vida'].plot(kind='line', figsize=(8, 4), title='Esperanza de vida')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_6['Esperanza de vida'].plot(kind='line', figsize=(8, 4), title='Esperanza de vida')
plt.gca().spines[['top', 'right']].set_visible(False)
